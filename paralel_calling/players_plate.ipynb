# %%
import requests 
import json
import os
from getpass import getpass
import pandas as pd
from pandas import json_normalize
#import tweepy
import time
from datetime import datetime
import sys
sys.path.append('../')
#from src import functions as fn 
from src import gathering as ga

from riotwatcher import LolWatcher, ApiError

# %%
with open("../data/players_list.json") as json_file:
    data = json.load(json_file)
ga.build_list(data[6660:9990])
# Out:
# 10  players info fixed
# 20  players info fixed
# 30  players info fixed
# 40  players info fixed
# 50  players info fixed
# <Response [429]> 72
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/SaucisseEnBoite?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player SaucisseEnBoite no longer exists
# 60  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/TRICKSY VICKSY?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player TRICKSY VICKSY no longer exists
# 70  players info fixed
# 80  players info fixed
# 90  players info fixed
# 100  players info fixed
# <Response [429]> 73
# 110  players info fixed
# 120  players info fixed
# 130  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/DIE FOR VISION?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player DIE FOR VISION no longer exists
# 140  players info fixed
# 150  players info fixed
# <Response [429]> 77
# 160  players info fixed
# 170  players info fixed
# 180  players info fixed
# 190  players info fixed
# 200  players info fixed
# <Response [429]> 59
# 210  players info fixed
# 220  players info fixed
# 230  players info fixed
# 240  players info fixed
# 250  players info fixed
# <Response [429]> 75
# 260  players info fixed
# 270  players info fixed
# 280  players info fixed
# 290  players info fixed
# 300  players info fixed
# <Response [429]> 81
# 310  players info fixed
# 320  players info fixed
# 330  players info fixed
# 340  players info fixed
# 350  players info fixed
# <Response [429]> 71
# 360  players info fixed
# 370  players info fixed
# 380  players info fixed
# 390  players info fixed
# 400  players info fixed
# <Response [429]> 73
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Schniggolei?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player Schniggolei no longer exists
# 420  players info fixed
# 430  players info fixed
# 440  players info fixed
# 450  players info fixed
# <Response [429]> 71
# 460  players info fixed
# 470  players info fixed
# 480  players info fixed
# 490  players info fixed
# 500  players info fixed
# <Response [429]> 78
# 510  players info fixed
# 520  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Binn fangirl?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player Binn fangirl no longer exists
# 530  players info fixed
# 540  players info fixed
# 550  players info fixed
# <Response [429]> 80
# 560  players info fixed
# 570  players info fixed
# 580  players info fixed
# 590  players info fixed
# 600  players info fixed
# <Response [429]> 62
# 610  players info fixed
# 620  players info fixed
# 630  players info fixed
# 640  players info fixed
# 650  players info fixed
# <Response [429]> 75
# 660  players info fixed
# 670  players info fixed
# 680  players info fixed
# 690  players info fixed
# 700  players info fixed
# <Response [429]> 85
# 710  players info fixed
# 720  players info fixed
# 730  players info fixed
# 740  players info fixed
# 750  players info fixed
# <Response [429]> 85
# 760  players info fixed
# 770  players info fixed
# 780  players info fixed
# 790  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Wαjih?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player Wαjih no longer exists
# 800  players info fixed
# <Response [429]> 81
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/HïdeOnShroud?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player HïdeOnShroud no longer exists
# 810  players info fixed
# 820  players info fixed
# 830  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Nachtaktiv?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player Nachtaktiv no longer exists
# 840  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Súck My Soldiers?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player Súck My Soldiers no longer exists
# 850  players info fixed
# <Response [429]> 75
# 860  players info fixed
# 870  players info fixed
# 880  players info fixed
# 890  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Unluckyskypaow?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player Unluckyskypaow no longer exists
# 900  players info fixed
# <Response [429]> 83
# 910  players info fixed
# 920  players info fixed
# 930  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Rαmireż?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player Rαmireż no longer exists
# 940  players info fixed
# 950  players info fixed
# <Response [429]> 73
# 960  players info fixed
# 970  players info fixed
# 980  players info fixed
# 990  players info fixed
# 1000  players info fixed
# <Response [429]> 83
# 1010  players info fixed
# 1020  players info fixed
# 1030  players info fixed
# 1040  players info fixed
# 1050  players info fixed
# <Response [429]> 84
# 1060  players info fixed
# 1070  players info fixed
# 1080  players info fixed
# 1090  players info fixed
# 1100  players info fixed
# <Response [429]> 79
# 1110  players info fixed
# 1120  players info fixed
# 1130  players info fixed
# 1140  players info fixed
# 1150  players info fixed
# <Response [429]> 82
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Menføu?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player Menføu no longer exists
# 1170  players info fixed
# 1180  players info fixed
# 1190  players info fixed
# 1200  players info fixed
# <Response [429]> 82
# 1210  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Tenshÿ?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player Tenshÿ no longer exists
# 1220  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/iwouldntkillyou?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player iwouldntkillyou no longer exists
# 1240  players info fixed
# 1250  players info fixed
# <Response [429]> 81
# 1260  players info fixed
# 1270  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Project Moe?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player Project Moe no longer exists
# 1280  players info fixed
# 1290  players info fixed
# 1300  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Anandamaya?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player Anandamaya no longer exists
# <Response [429]> 52
# 1310  players info fixed
# 1320  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Misthuhn?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player Misthuhn no longer exists
# 1330  players info fixed
# 1340  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/TuÅbuelaMûerta?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player TuÅbuelaMûerta no longer exists
# 1350  players info fixed
# <Response [429]> 70
# 1360  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Ghost Okami III?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player Ghost Okami III no longer exists
# 1370  players info fixed
# 1380  players info fixed
# 1390  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Ya Ba Da Jie Bao?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player Ya Ba Da Jie Bao no longer exists
# 1400  players info fixed
# 1410  players info fixed
# <Response [429]> 82
# 1420  players info fixed
# 1430  players info fixed
# 1440  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Δ ΙΞΚKΘ Δ?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player Δ ΙΞΚKΘ Δ no longer exists
# 1450  players info fixed
# 1460  players info fixed
# <Response [429]> 77
# 1470  players info fixed
# 1480  players info fixed
# 1490  players info fixed
# 1500  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/IsoObu?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player IsoObu no longer exists
# 1510  players info fixed
# <Response [429]> 60
# 1520  players info fixed
# 1530  players info fixed
# 1540  players info fixed
# 1550  players info fixed
# 1560  players info fixed
# <Response [429]> 68
# 1570  players info fixed
# 1580  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/LolisFunTheySaid?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player LolisFunTheySaid no longer exists
# 1590  players info fixed
# 1600  players info fixed
# 1610  players info fixed
# <Response [429]> 80
# 1620  players info fixed
# 1630  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Kim Ji Min?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player Kim Ji Min no longer exists
# 1640  players info fixed
# 1650  players info fixed
# 1660  players info fixed
# <Response [429]> 85
# 1670  players info fixed
# 1680  players info fixed
# 1690  players info fixed
# 1700  players info fixed
# 1710  players info fixed
# <Response [429]> 82
# 1720  players info fixed
# 1730  players info fixed
# 1740  players info fixed
# 1750  players info fixed
# 1760  players info fixed
# <Response [429]> 80
# 1770  players info fixed
# 1780  players info fixed
# 1790  players info fixed
# 1800  players info fixed
# 1810  players info fixed
# <Response [429]> 71
# 1820  players info fixed
# 1830  players info fixed
# 1840  players info fixed
# 1850  players info fixed
# 1860  players info fixed
# <Response [429]> 72
# 1870  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Kolorat?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player Kolorat no longer exists
# 1880  players info fixed
# 1890  players info fixed
# 1900  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Koyuki Seri ?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player Koyuki Seri  no longer exists
# 1910  players info fixed
# <Response [429]> 84
# 1920  players info fixed
# 1930  players info fixed
# 1940  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Slagged?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player Slagged no longer exists
# 1950  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Slagged?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player Slagged no longer exists
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/FNC xBukkake?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player FNC xBukkake no longer exists
# 1960  players info fixed
# <Response [429]> 75
# 1970  players info fixed
# 1980  players info fixed
# 1990  players info fixed
# 2000  players info fixed
# 2010  players info fixed
# <Response [429]> 84
# 2020  players info fixed
# 2030  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/White Slaves?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player White Slaves no longer exists
# 2040  players info fixed
# 2050  players info fixed
# 2060  players info fixed
# <Response [429]> 78
# 2070  players info fixed
# 2080  players info fixed
# 2090  players info fixed
# 2100  players info fixed
# 2110  players info fixed
# <Response [429]> 69
# 2120  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Cassio c cool?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player Cassio c cool no longer exists
# 2130  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/succ my nut?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player succ my nut no longer exists
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Show Me Blood?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player Show Me Blood no longer exists
# 2150  players info fixed
# 2160  players info fixed
# <Response [429]> 85
# 2170  players info fixed
# 2180  players info fixed
# 2190  players info fixed
# 2200  players info fixed
# 2210  players info fixed
# <Response [429]> 72
# 2220  players info fixed
# 2230  players info fixed
# 2240  players info fixed
# 2250  players info fixed
# 2260  players info fixed
# <Response [429]> 70
# 2270  players info fixed
# 2280  players info fixed
# 2290  players info fixed
# 2300  players info fixed
# 2310  players info fixed
# <Response [429]> 80
# 2320  players info fixed
# 2330  players info fixed
# 2340  players info fixed
# 2350  players info fixed
# 2360  players info fixed
# <Response [429]> 80
# 2370  players info fixed
# 2380  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/TheSlumpGod vA?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player TheSlumpGod vA no longer exists
# 2390  players info fixed
# 2400  players info fixed
# 2410  players info fixed
# <Response [429]> 69
# 2420  players info fixed
# 2430  players info fixed
# 2440  players info fixed
# 2450  players info fixed
# 2460  players info fixed
# <Response [429]> 85
# 2470  players info fixed
# 2480  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Hafþór?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player Hafþór no longer exists
# 2490  players info fixed
# 2500  players info fixed
# 2510  players info fixed
# <Response [429]> 78
# 2520  players info fixed
# 2530  players info fixed
# 2540  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Peru Man?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player Peru Man no longer exists
# 2550  players info fixed
# 2560  players info fixed
# <Response [429]> 82
# 2570  players info fixed
# 2580  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/NoPleaseDontDoIt?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player NoPleaseDontDoIt no longer exists
# 2590  players info fixed
# 2600  players info fixed
# 2610  players info fixed
# <Response [429]> 83
# 2620  players info fixed
# 2630  players info fixed
# 2640  players info fixed
# 2650  players info fixed
# 2660  players info fixed
# <Response [429]> 81
# 2670  players info fixed
# 2680  players info fixed
# 2690  players info fixed
# 2700  players info fixed
# 2710  players info fixed
# <Response [429]> 83
# 2720  players info fixed
# 2730  players info fixed
# 2740  players info fixed
# 2750  players info fixed
# 2760  players info fixed
# <Response [429]> 82
# 2770  players info fixed
# 2780  players info fixed
# 2790  players info fixed
# 2800  players info fixed
# 2810  players info fixed
# <Response [429]> 84
# 2820  players info fixed
# 2830  players info fixed
# 2840  players info fixed
# 2850  players info fixed
# 2860  players info fixed
# <Response [429]> 69
# 2870  players info fixed
# 2880  players info fixed
# 2890  players info fixed
# 2900  players info fixed
# 2910  players info fixed
# <Response [429]> 83
# 2920  players info fixed
# 2930  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/K1D High Hopes?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player K1D High Hopes no longer exists
# 2940  players info fixed
# 2950  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/L9 ANNE FRANK?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player L9 ANNE FRANK no longer exists
# 2960  players info fixed
# <Response [429]> 68
# 2970  players info fixed
# 2980  players info fixed
# 2990  players info fixed
# 3000  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/MBE Zbeedy01?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player MBE Zbeedy01 no longer exists
# 3010  players info fixed
# 3020  players info fixed
# <Response [429]> 78
# 3030  players info fixed
# 3040  players info fixed
# 3050  players info fixed
# 3060  players info fixed
# 3070  players info fixed
# <Response [429]> 83
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/TRICKSTÆR ?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player TRICKSTÆR  no longer exists
# 3080  players info fixed
# 3090  players info fixed
# 3100  players info fixed
# 3110  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Galouli Kedaba?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player Galouli Kedaba no longer exists
# 3120  players info fixed
# <Response [429]> 79
# 3130  players info fixed
# 3140  players info fixed
# 3150  players info fixed
# 3160  players info fixed
# 3170  players info fixed
# <Response [429]> 79
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/FrozenBootySweat?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player FrozenBootySweat no longer exists
# 3180  players info fixed
# 3190  players info fixed
# 3200  players info fixed
# 3210  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/African Toe?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player African Toe no longer exists
# 3220  players info fixed
# <Response [429]> 86
# 3230  players info fixed
# 3240  players info fixed
# 3250  players info fixed
# 3260  players info fixed
# BREAK! https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/thaolelelele?api_key=RGAPI-7c32dc6d-b49c-4853-b801-4bc7b93f5782   <Response [404]>
# player thaolelelele no longer exists
# 3270  players info fixed
# <Response [429]> 87
# 3280  players info fixed
# 3290  players info fixed
# 3300  players info fixed
# 3310  players info fixed
# 3320  players info fixed
# <Response [429]> 86
# 3330  players info fixed
# done
